# %% [markdown]
# # [Tarefas](https://drive.google.com/drive/folders/1ghEXoCWBAW3MgR8H3JHvOzITG2VNkNi8?usp=sharing) - Álgebra Linear Computacional
#
# * **Aluna:** Bárbara Neves
# * **Matrícula:** 507526
#
# ### **Especificações**
#
# Trabalhos da disciplina de Álgebra Linear Computacional do programa de Mestrado e Doutorado em Ciência da Computação da Universidade Federal do Ceará (MDCC/UFC)
#
# > Tarefas feitas em *Python* via *Google Colab*

# %% [markdown]
# # [Resolução de Sistemas de Equações Algébricas](https://drive.google.com/drive/folders/1Qgq6Aj5dKCauwp8RrdsOBmOaTvbtacRu?usp=sharing)

# %% [markdown]
# ## [Tarefa 01](https://drive.google.com/file/d/11_AN2sRKLnsKLpvTE-HmmmivLIjhlO0w/view?usp=sharing) - Eliminação de Gauss

# %% [markdown]
# ## [Tarefa 02](https://drive.google.com/file/d/1BNrNNhFJw1NkfTY1QFVaG_SvJk325cW_/view?usp=sharing) - Eliminação de Gauss-Jordan

# %% [markdown]
# ## [Tarefa 03](https://drive.google.com/file/d/1tQe_99pbQ0H3CsRGKStheHXhL6tUdTaA/view?usp=sharing) - Decomposição LU e Resolução de Sistemas Lineares

# %% [markdown]
# ## [Tarefa 04](https://drive.google.com/file/d/1M3AYvtxCQXszpujtIroP8JVZKGvo6Mjl/view?usp=sharing) - Decomposição de Cholesky

# %% [markdown]
# ## [Tarefa 06](https://drive.google.com/file/d/13k79HrdbLhNsSnH3-MySaRE0laSem9IH/view?usp=sharing) - Ortogonalização de Gram-Schmidt

# %% [markdown]
# ## [Tarefa 05](https://drive.google.com/file/d/1eXByst0MXgycWQd15Xd6cZMO7FpGwpON/view?usp=sharing) - RREF

# %% [markdown]
# ## [Tarefa 07](https://drive.google.com/file/d/1wnk3UwHv07qoq9CqduD3xPaAfGVVmwXn/view?usp=sharing) - Mínimos Quadrados

# %% [markdown]
# # [Autovalores e Autovetores](https://drive.google.com/drive/folders/1EWWEl56N1CHdSGacq7hN03mLer532P7N?usp=sharing)

# %% [markdown]
# ## [Tarefa 08](https://drive.google.com/file/d/1qp7zh1aLuV5i1c5hOdD2dNuESuudJtH-/view?usp=sharing) - Métodos de Potência

# %% [markdown]
# ## [Tarefa 09](https://) - Método de Householder (Transformação de Similaridade)

# %% [markdown]
# ## [Tarefa 10](https://drive.google.com/file/d/150kfYMeCknEra2Ys-u9o-OseS90F9NEH/view?usp=sharing) - Decomposição QR

# %% [markdown]
# ## [Tarefa 11](https://drive.google.com/file/d/1Ar1BijR9jYNrEfF7Os67rmZOBCQrNq1d/view?usp=sharing) - Método QR para Autovalores e Autovetores

# %% [markdown]
# ## [Tarefa 12](https://drive.google.com/file/d/1yP686Gfq4a96m5cd67tseqF4UWVfupLN/view?usp=sharing) - Decomposição SVD

# %% [markdown]
# # [Métodos Iterativos para Solução de Sistemas de Equações Algébricas](https://drive.google.com/drive/folders/1ULjcX1feCfMH_f9tXBQIgU-6CucaZNME?usp=sharing)

# %% [markdown]
# ## [Tarefa 13](https://drive.google.com/file/d/1QfFSeYB-ROxI0xlfXVUKTgwj8sU-OOFH/view?usp=sharing) - SOR
